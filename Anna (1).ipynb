# %% [markdown]
# Submetric: Parks
# ======

# %% [markdown]
# Introduction
# ------

# %% [markdown]
# Access to parks is a contributing factor in encouraging residents to go outside for recreational purposes. The idea is that the more parks there are in a neighborhood, the easier it is for a resident in that neighborhood to reasonably travel to a park or be motivated to do so. This engagement with parks is directly related to our main metric, Touching Grass, as parks are outside and generally have grass to touch.
#
# This submetric (Parks in Pittsburgh neighborhoods) uses a dataset that includes information about names and locations of parks in Pittsburgh. To create a measurable and comparable submetric, I chose the quantitative value of # of parks in each neighborhood as the definition of this submetric.

# %% [markdown]
# ## Selecting a dataset

# %% [markdown]
# The dataset has 200+ data points and comes from the City of Pittsburgh.
#
# WPRDC has a dataset with better recency about parks in Pittsburgh up. Despite this, I selected the less recent dataset because it could be sorted by neighborhood which is more useful for the purposes of this project. The difference in recency was not large within the context of measuring the # of parks, which is not a value expected to change significantly in a short time period. If I had chosen to define the submetric through total acreage of parks in a neighborhood, the other dataset would be better. However, I believe the actual # of parks as opposed to size supports our main metric better because having multiple locations means parks are more accessible for people living in different parts of the neighborhood.

# %% [markdown]
# ## Code & Graphs

# %% [markdown]
# First, libraries and the dataset as a csv is imported

# %%
#importing in libraries used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load in dataset csv
dataset = pd.read_csv("https://data.wprdc.org/datastore/dump/fa329e3d-89ff-4708-8ddf-81bfedcad11d", index_col = "_id")

# %% [markdown]
# Let's look at the dataset:

# %%
dataset.head() #Display csv dataset in jupyterhub
# Out:
#              id                     name  type maintenance_responsibility  \
# _id
# 1    2111959181           Able Long Park  Park           Parks - Southern
# 2    1109513049  Albert Turk Graham Park  Park           Parks - Schenley
# 3    1544096765               Alcoa Park  Park           Parks - Northern
# 4    1212681573        Allegheny Commons  Park           Parks - Northern
# 5     954863286   Allegheny Landing Park  Park           Parks - Northern
#
#                                                  image      neighborhood  \
# _id
# 1    https://tools.wprdc.org/images/pittsburgh/park...         Beechview
# 2    https://tools.wprdc.org/images/pittsburgh/park...  Crawford-Roberts
# 3                                                  NaN       North Shore
# 4                                                  NaN  Allegheny Center
# 5                                                  NaN       North Shore
#
#      council_district  ward        tract  public_works_division  pli_division  \
# _id
# 1                   4    19  42003192000                      5            19
# 2                   6     3  42003030500                      3             3
# 3                   1    22  42003563200                      6            22
# 4                   1    22  42003562700                      1            22
# 5                   1    22  42003563200                      6            22
#
#      police_zone fire_zone   latitude  longitude
# _id
# 1              6      4-28  40.408118 -80.028197
# 2              2       2-1  40.440507 -79.984018
# 3              1      1-20  40.447481 -80.001017
# 4              1       1-7  40.453126 -80.009158
# 5              1      1-20  40.447184 -80.002907

# %% [markdown]
# Not every column is needed for the project, so to clean it up only relevant columns are selected (name, type, and neighborhood).

# %%
parks = dataset[['name', 'type', 'neighborhood']] 
#create a new dataset using the original that only includes columns for name, type, and neighborhood

parks.sort_values(by="neighborhood").head(16) #Display first 16 rows of data from the new dataset
# Out:
#                                             name                   type  \
# _id
# 32       Buhl Community Park at Allegheny Square                   Park
# 4                              Allegheny Commons                   Park
# 56            Emerald View Park - Grandview Park                   Park
# 57         Emerald View Park - Bigbee Field Park                   Park
# 46                             Devlin Field Park                   Park
# 17                        Banksville School Park                   Park
# 16                               Banksville Park                   Park
# 10                                    Ammon Park                   Park
# 1                                 Able Long Park                   Park
# 23   Beechview Healthy Active Living Center Park                   Park
# 186                                 Vanucci Park                   Park
# 22                            Beechview Monument      Monument/Memorial
# 182                                Tropical Park                   Park
# 8                                     Alton Park                   Park
# 151                                 Pauline Park                   Park
# 86                          Grant Street Islands  Traffic Island/Median
#
#           neighborhood
# _id
# 32    Allegheny Center
# 4     Allegheny Center
# 56           Allentown
# 57           Allentown
# 46           Arlington
# 17          Banksville
# 16          Banksville
# 10   Bedford Dwellings
# 1            Beechview
# 23           Beechview
# 186          Beechview
# 22           Beechview
# 182          Beechview
# 8            Beechview
# 151          Beechview
# 86           Beechview

# %% [markdown]
# You may notice that not every "park" listed in this dataset is actually a park! Things like traffic islands are not what we are looking for or considering as a "park" and would not have that much of an impact on residents touching grass. Let's select for only true parks to stay true to the chosen submetric.

# %%
query_mask = parks['type'] == "Park" #Create a query mask to look for only parks
parks_only = parks[query_mask]

parks_rank = pd.DataFrame()
parks_rank["num_parks"] = parks_only.groupby("neighborhood").size() 
#create a column that describes the number of parks in each neighborhood

parks_sorted = parks_rank.sort_values(by=['num_parks'], ascending=False) #sort the data by # of parks 
parks_sorted.head() #Display data
# Out:
#                    num_parks
# neighborhood
# Beechview                  6
# South Side Slopes          6
# Hazelwood                  5
# Troy Hill                  5
# Mount Washington           5

# %% [markdown]
# Now we can see that these are the neighborhoods with the most amounts of parks.

# %%
#Add fun coloring to the bars based off of y-axis values
norm = plt.Normalize(np.min(parks_sorted["num_parks"]), np.max(parks_sorted["num_parks"])) #normalize bar values
colmap = plt.cm.YlGn #import colormap from matplotlib
colors = [colmap(norm(y)) for y in parks_sorted["num_parks"]] #apply colormap to bars based on value

parks_sorted['num_parks'].plot(kind="barh", width = .4, figsize=(25,20), position=0, color=colors, fontsize=16) #plot data

plt.ylabel('Neighborhood', fontsize =30) #label x-axis as 'Neighborhood'
plt.xlabel('Number of parks', fontsize=30) #label y-axis as 'Number of parks'
plt.title('Parks in Pittsburgh Neighborhoods', fontsize=35) #Add graph title

plt.tight_layout()
plt.gca().invert_yaxis() 

plt.show() #Display the graph

# %%
parks_sorted["rank"] = parks_sorted["num_parks"].rank(method="min",ascending=False)
'''Add a column for ranking neighborhoods based off of number of parks, with #1 being the greatest
amount of parks'''

parks_sorted.groupby("rank").head() #Display data with rank included
# Out:
#                      num_parks  rank
# neighborhood
# Beechview                    6   1.0
# South Side Slopes            6   1.0
# Hazelwood                    5   3.0
# Troy Hill                    5   3.0
# Mount Washington             5   3.0
# East Liberty                 4   6.0
# Marshall-Shadeland           4   6.0
# Elliott                      4   6.0
# Sheraden                     4   6.0
# North Shore                  3  10.0
# South Oakland                3  10.0
# Upper Lawrenceville          3  10.0
# Beltzhoover                  3  10.0
# Squirrel Hill South          3  10.0
# Westwood                     2  25.0
# Allentown                    2  25.0
# Banksville                   2  25.0
# Allegheny Center             2  25.0
# Spring Garden                2  25.0
# Arlington                    1  43.0
# Bedford Dwellings            1  43.0
# Fairywood                    1  43.0
# Homewood South               1  43.0
# Homewood West                1  43.0

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Based off of the data depicted in the graph, it appears that **Beechview** and **Southside Slopes** are the neighborhoods with the most parks in Pittsburgh, with 6 parks each. My personal favorite neighborhood is Southside Flats, which has 3 parks. This is probably because my personal metric for my favorite neighborhood doesn't involve parks, since I don't frequent them.
